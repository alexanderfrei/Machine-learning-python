# %%
# Out:
#   File "<ipython-input-3-f8512346672e>", line 2
#     Сформируйте систему линейных уравнений (то есть задайте матрицу коэффициентов A и свободный вектор b) для многочлена первой степени, который должен совпадать с функцией f в точках 1 и 15. Решите данную систему с помощью функции scipy.linalg.solve. Нарисуйте функцию f и полученный многочлен. Хорошо ли он приближает исходную функцию?
#                       ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.linalg import solve
# %matplotlib inline

# %%
# Рассмотрим сложную математическую функцию на отрезке [1, 15]:
# f(x) = sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)

def f(x):
    return np.sin(x/5) * np.exp(x/10) + 5 * np.exp(-x/2)

y = []    
for x in np.arange(1,16):
    y.append(f(x))

# %%
# plt.plot(y) # check

# %%
# Сформируйте систему линейных уравнений (то есть задайте матрицу коэффициентов A и свободный вектор b) для многочлена первой степени, который должен совпадать с функцией f в точках 1 и 15. 
# Решите данную систему с помощью функции scipy.linalg.solve. 
b = np.array([y[0], y[14]])
a = np.array([[1,1],[1,15]])
x = solve(a,b)

# %%
# Нарисуйте функцию f и полученный многочлен. Хорошо ли он приближает исходную функцию?
y_ = []
for c in np.arange(1,16):
    y_.append(x[0] + x[1]*c)
plt.plot(y)
plt.plot(y_)

# %%
b = np.array([y[0], y[7], y[14]])
a = np.array([[1,1,1],
              [1,8,64],
              [1,15,225]])
x = solve(a,b)

# %%
# Повторите те же шаги для многочлена второй степени, который совпадает с функцией f в точках 1, 8 и 15. Улучшилось ли качество аппроксимации?
y_ = []
for c in np.arange(1,16):
    y_.append(x[0] + x[1]*c + x[2]*c**2)
plt.plot(y)
plt.plot(y_)

# %%
b = np.array([y[0], y[3], y[9], y[14]])
a = np.array([[1,1,1,1],
              [1,4,16,64],
              [1,10,100,1000],
              [1,15,225,15**3]
             ])
x = solve(a,b)

# %%
# Повторите те же шаги для многочлена третьей степени, который совпадает с функцией f в точках 1, 4, 10 и 15. Хорошо ли он аппроксимирует функцию? Коэффициенты данного многочлена (четыре числа в следующем порядке: w_0, w_1, w_2, w_3) являются ответом на задачу. Округлять коэффициенты не обязательно, но при желании можете произвести округление до второго знака (т.е. до числа вида 0.42)
y_ = []
for c in np.arange(1,16):
    y_.append(x[0] + x[1]*c + x[2]*c**2 + x[3]*c**3)
plt.plot(y)
plt.plot(y_)

# %%
with open('sub2.txt', 'w') as sub:
    sub.write(' '.join([str(idx) for idx in x]))
