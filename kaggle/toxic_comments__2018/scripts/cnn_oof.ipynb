# %%
import pickle
import time

import numpy as np
import pandas as pd

import tensorflow as tf
from keras.models import Model
from keras.layers import Dense, Embedding, Input, Concatenate, Conv1D, Activation, TimeDistributed, Flatten, RepeatVector, Permute, multiply
from keras.layers import LSTM, Bidirectional, GlobalMaxPool1D, Dropout, GRU, GlobalAveragePooling1D, MaxPooling1D, SpatialDropout1D, BatchNormalization
from keras.preprocessing import text, sequence
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from keras.optimizers import Adam
from keras import backend as K

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score

import gc

np.set_printoptions(precision=8, suppress=True)
# Out:
# C:\dev\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def np_rank(array):
    ranks = np.empty_like(array)
    for i in np.arange(array.shape[1]):
        temp = array[:, i].argsort()
        ranks[temp, i] = np.arange(len(array))
    return ranks

# %%
with open("../dumps/cnn_dump.pkl", "rb") as f:
    X_train, X_test, y, embedding_matrix = pickle.load(file=f)
train = pd.read_csv("../input/train.csv")
test = pd.read_csv("../input/test.csv")    
sample_submission = pd.read_csv("../input/sample_submission.csv")

# %%
min_count = 10 #the minimum required word frequency in the text
max_features = 27403 #it's from previous run with min_count=10
maxlen = 150 #padding length
num_folds = 10 #number of folds
batch_size = 512 
embed_size = 300 #embeddings dimension
epochs = 4
seed = 42

# %%
def get_model_cnn(X_train):
    global embed_size
    inp = Input(shape=(maxlen, ), name="text")
    num_vars = Input(shape=[X_train["num_vars"].shape[1]], name="num_vars")
    x = Embedding(max_features, embed_size, weights=[embedding_matrix])(inp)
    x = SpatialDropout1D(0.2)(x)
    z = GlobalMaxPool1D()(x)
    x = Conv1D(embed_size, 4, activation="relu")(x)
    x = GlobalMaxPool1D()(x)
    x = Concatenate()([x,z,num_vars])
    x = Dropout(0.3)(x)
    x = Dense(6, activation="sigmoid")(x)
    model = Model(inputs=[inp,num_vars], outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
class RocAucEvaluation(Callback):
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()
        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            print("\n ROC-AUC - epoch: %d - score: %.6f \n" % (epoch+1, score))

# %%
# X_tra, X_val = {}, {}
# X_tra['text'], X_val['text'], y_tra, y_val = train_test_split(X_train['text'], y, 
#                                                               train_size=0.95, random_state=233)
# X_tra['num_vars'], X_val['num_vars'], _, _ = train_test_split(X_train['num_vars'], y, 
#                                                               train_size=0.95, random_state=233)
# RocAuc = RocAucEvaluation(validation_data=(X_val, y_val), interval=1)

# model.fit(X_tra, y_tra, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val),
#           callbacks=[RocAuc])

# y_pred = model.predict(X_test, batch_size=1024)
# submission[["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]] = y_pred
# submission.to_csv("../output/cnn_conv1D_emb_num_NOCV.csv.gz", compression="gzip", index=False)

# %%
# OOF
scores = []
train_predict = np.zeros((train.shape[0],6))
test_predict = np.zeros((test.shape[0],6))
kf = KFold(n_splits=num_folds, shuffle=True, random_state=seed)

for train_index, valid_index in kf.split(X_train['num_vars']):
    
    kfold_X_train = {}
    kfold_X_valid = {}
    kfold_y_train, kfold_y_valid = y[train_index], y[valid_index]
    for c in ['text','num_vars']:
        kfold_X_train[c] = X_train[c][train_index]
        kfold_X_valid[c] = X_train[c][valid_index]

    model = get_model_cnn(X_train)
    RocAuc = RocAucEvaluation(validation_data=(kfold_X_valid, kfold_y_valid), interval=1)
    model.fit(kfold_X_train, kfold_y_train, batch_size=batch_size, epochs=epochs, verbose=1,
              validation_data=(kfold_X_valid, kfold_y_valid), callbacks=[RocAuc])
    train_predict[valid_index] = model.predict(kfold_X_valid, batch_size=batch_size)
    test_predict += np_rank(model.predict(X_test, batch_size=batch_size))
    cv_score = roc_auc_score(kfold_y_valid, train_predict[valid_index])
    scores.append(cv_score)     
    
    # release memory
    del model
    gc.collect()
    K.clear_session()    
    
test_predict /= num_folds
# Out:
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/4
# 143613/143613 [==============================] - 34s 234us/step - loss: 0.0843 - acc: 0.9724 - val_loss: 0.0470 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 1 - score: 0.971978
#
# Epoch 2/4
# 143613/143613 [==============================] - 32s 223us/step - loss: 0.0504 - acc: 0.9819 - val_loss: 0.0439 - val_acc: 0.9839
#
#  ROC-AUC - epoch: 2 - score: 0.984528
#
# Epoch 3/4
# 143613/143613 [==============================] - 32s 225us/step - loss: 0.0445 - acc: 0.9835 - val_loss: 0.0442 - val_acc: 0.9834
#
#  ROC-AUC - epoch: 3 - score: 0.985993
#
# Epoch 4/4
# 143613/143613 [==============================] - 32s 224us/step - loss: 0.0401 - acc: 0.9849 - val_loss: 0.0428 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 4 - score: 0.986568
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 33s 227us/step - loss: 0.0771 - acc: 0.9750 - val_loss: 0.0494 - val_acc: 0.9817
#
#  ROC-AUC - epoch: 1 - score: 0.980584
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0490 - acc: 0.9822 - val_loss: 0.0463 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 2 - score: 0.985738
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0436 - acc: 0.9838 - val_loss: 0.0455 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 3 - score: 0.986806
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0394 - acc: 0.9851 - val_loss: 0.0467 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 4 - score: 0.987015
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 32s 224us/step - loss: 0.0758 - acc: 0.9755 - val_loss: 0.0489 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 1 - score: 0.979061
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0491 - acc: 0.9822 - val_loss: 0.0459 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 2 - score: 0.984295
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0436 - acc: 0.9838 - val_loss: 0.0451 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 3 - score: 0.985376
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0393 - acc: 0.9851 - val_loss: 0.0459 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 4 - score: 0.985585
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0803 - acc: 0.9740 - val_loss: 0.0502 - val_acc: 0.9815
#
#  ROC-AUC - epoch: 1 - score: 0.978432
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0493 - acc: 0.9822 - val_loss: 0.0474 - val_acc: 0.9820
#
#  ROC-AUC - epoch: 2 - score: 0.985116
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0438 - acc: 0.9837 - val_loss: 0.0461 - val_acc: 0.9826
#
#  ROC-AUC - epoch: 3 - score: 0.985970
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0396 - acc: 0.9851 - val_loss: 0.0465 - val_acc: 0.9822
#
#  ROC-AUC - epoch: 4 - score: 0.986277
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 32s 224us/step - loss: 0.0856 - acc: 0.9723 - val_loss: 0.0473 - val_acc: 0.9826
#
#  ROC-AUC - epoch: 1 - score: 0.976017
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0499 - acc: 0.9820 - val_loss: 0.0438 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 2 - score: 0.982081
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0442 - acc: 0.9836 - val_loss: 0.0434 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 3 - score: 0.983588
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 225us/step - loss: 0.0398 - acc: 0.9848 - val_loss: 0.0430 - val_acc: 0.9841
#
#  ROC-AUC - epoch: 4 - score: 0.983717
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 33s 226us/step - loss: 0.0787 - acc: 0.9747 - val_loss: 0.0455 - val_acc: 0.9833
#
#  ROC-AUC - epoch: 1 - score: 0.982158
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 224us/step - loss: 0.0494 - acc: 0.9823 - val_loss: 0.0425 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 2 - score: 0.986495
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 225us/step - loss: 0.0436 - acc: 0.9838 - val_loss: 0.0424 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 3 - score: 0.986751
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 225us/step - loss: 0.0397 - acc: 0.9850 - val_loss: 0.0431 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 4 - score: 0.986673
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 33s 227us/step - loss: 0.0793 - acc: 0.9747 - val_loss: 0.0505 - val_acc: 0.9815
#
#  ROC-AUC - epoch: 1 - score: 0.978478
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 224us/step - loss: 0.0495 - acc: 0.9819 - val_loss: 0.0471 - val_acc: 0.9823
#
#  ROC-AUC - epoch: 2 - score: 0.984967
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 225us/step - loss: 0.0439 - acc: 0.9837 - val_loss: 0.0457 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 3 - score: 0.985869
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 226us/step - loss: 0.0395 - acc: 0.9851 - val_loss: 0.0468 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 4 - score: 0.986009
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 32s 226us/step - loss: 0.0796 - acc: 0.9746 - val_loss: 0.0471 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 1 - score: 0.975399
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0489 - acc: 0.9821 - val_loss: 0.0442 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 2 - score: 0.983567
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0438 - acc: 0.9836 - val_loss: 0.0434 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 3 - score: 0.984582
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 222us/step - loss: 0.0391 - acc: 0.9852 - val_loss: 0.0433 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 4 - score: 0.983776
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 32s 225us/step - loss: 0.0857 - acc: 0.9730 - val_loss: 0.0480 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 1 - score: 0.978402
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0498 - acc: 0.9819 - val_loss: 0.0444 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 2 - score: 0.985445
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 224us/step - loss: 0.0442 - acc: 0.9836 - val_loss: 0.0432 - val_acc: 0.9839
#
#  ROC-AUC - epoch: 3 - score: 0.987236
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0398 - acc: 0.9850 - val_loss: 0.0432 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 4 - score: 0.987496
#
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/4
# 143614/143614 [==============================] - 32s 224us/step - loss: 0.0806 - acc: 0.9736 - val_loss: 0.0508 - val_acc: 0.9817
#
#  ROC-AUC - epoch: 1 - score: 0.974438
#
# Epoch 2/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0494 - acc: 0.9821 - val_loss: 0.0479 - val_acc: 0.9823
#
#  ROC-AUC - epoch: 2 - score: 0.981169
#
# Epoch 3/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0438 - acc: 0.9837 - val_loss: 0.0465 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 3 - score: 0.982867
#
# Epoch 4/4
# 143614/143614 [==============================] - 32s 223us/step - loss: 0.0398 - acc: 0.9851 - val_loss: 0.0464 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 4 - score: 0.982751

# %%
test_predict /= test_predict.shape[0]
roc_auc_score(y, train_predict), scores
# Out:
# (0.9851916984923461,
#  [0.9865682690274534,
#   0.9870149692251476,
#   0.9855850074512719,
#   0.9862767180504787,
#   0.9837170504234583,
#   0.9866728792566021,
#   0.9860085196168967,
#   0.9837759652301429,
#   0.9874957413096629,
#   0.9827511342639913])

# %%
submission = pd.concat([sample_submission.iloc[:, 0], 
                        pd.DataFrame(test_predict)], axis=1)
submission.columns = sample_submission.columns
# submission.to_csv("../output/cnn_conv1D_emb_num_5epochs.gz", compression="gzip", index=False)

# oof test
submission.to_csv("../output/test/cnn_conv1D_num.csv", index=False)

# oof train
train_oof = pd.concat([sample_submission.iloc[:, 0], pd.DataFrame(train_predict)], axis=1)
train_oof.to_csv("../output/train/cnn_conv1D_num.csv", index=False)
